# %% [markdown]
# <a href="https://colab.research.google.com/github/sanazgit/OpenCV/blob/main/Cropping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://learnandsupport.getolympus.com/sites/default/files/styles/rectangular_768px/public/2018-09/image2.jpg?itok=cnlxLsjR
# Out:
# --2023-06-02 10:09:47--  https://learnandsupport.getolympus.com/sites/default/files/styles/rectangular_768px/public/2018-09/image2.jpg?itok=cnlxLsjR
# Resolving learnandsupport.getolympus.com (learnandsupport.getolympus.com)... 23.185.0.2
# Connecting to learnandsupport.getolympus.com (learnandsupport.getolympus.com)|23.185.0.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36578 (36K) [image/jpeg]
# Saving to: ‘image2.jpg?itok=cnlxLsjR’
#
# image2.jpg?itok=cnl 100%[===================>]  35.72K  --.-KB/s    in 0s
#
# 2023-06-02 10:09:47 (96.0 MB/s) - ‘image2.jpg?itok=cnlxLsjR’ saved [36578/36578]

# %%
# !ls
# Out:
# 'image2.jpg?itok=cnlxLsjR'   sample_data

# %%
import cv2
import matplotlib.pyplot as plt

im= cv2.imread('image2.jpg')
plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))

# %%
im.shape
# Out:
# (576, 768, 3)

# %%
w,h= im.shape[:2]
cropped = im[0:388 , 340:710]
plt.imshow(cropped[...,::-1])

# %%
cv2.imwrite("new_face.jpg", cropped)
# Out:
# True
